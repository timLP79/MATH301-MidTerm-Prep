# %%
import sympy as sp
from sympy import Matrix, S, Rational

# %%
A = Matrix([[-6.3, -9.72, 7.3, -1.1], [-1.6, -2.07, -0.3, 2.7], [-2, 0.03, -7.4, 8.7], [9.9, 16.41, -8.7, -7.6]])

# %%
D_frac = A.applyfunc(lambda x: Rational(str(x)))
D_frac.rref()[0]
# Out:
# Matrix([
# [1, 0, 0,     3],
# [0, 1, 0, -10/3],
# [0, 0, 1,    -2],
# [0, 0, 0,     0]])

# %% [markdown]
# # Week 5 Group Activity Work

# %%
B = Matrix([[3, 2, -4, -11], [2, 3, -1, -9], [4, 2, -6, -14]])

# %%
B.rref()[0]
# Out:
# Matrix([
# [1, 0, -2, -3],
# [0, 1,  1, -1],
# [0, 0,  0,  0]])
