# %% [markdown]
# # Using Python in Linear Algebra

# %%
import numpy as np

# %%
print(np.sqrt(25))
# Out:
# 5.0

# %% [raw]
# SymPy allows us to perform symbolic calculations and get exact answers. So if you want an exact answer, then use sympy, if you want a decimal representation, then use numpy

# %%
import sympy as sp

# %%
c = sp.S("9/4")
d = sp.S("5/6")
print(c+d)
# Out:
# 37/12

# %% [raw]
# Here is an example of the difference between numpy and sympy

# %%
# using numpy
e = 2/np.sqrt(2)
print(e)
# Out:
# 1.414213562373095

# %%
# using sympy
f = 2/sp.sqrt(2)
f
# Out:
# sqrt(2)

# %%
import math

# %%
print(math.pi)
# Out:
# 3.141592653589793
