# %% [markdown]
# # WebWork

# %%
import sympy as sp
from sympy import Matrix, S, Rational

# %% [markdown]
# ## Problem 1

# %%
A = Matrix([[1, -3, 5],[1, -3, 5], [1, -3, 5] ])

# %%
A = Matrix([[0, 3, 7, 1],[0, 0, -2, 7], [0, 0, 0, 7] ])

# %%
A = Matrix([[2, -3],[-6, 9]])

# %%
A = Matrix([[7, -15], [-11, 22]])

# %%
A = Matrix([[3, -12, 6], [-3, 12, 5], [3, -12, 10]])

# %%
A = Matrix([[0, 3, 7, 1],[0, 0, -2, 7], [0, 0, 0, 7] ])

# %% [markdown]
# ## Problem 5

# %%
A = Matrix([[4, 26, 5],[3, 1, 0], [-5, 1, 3], [3, 5, -2], [-5, 8, 4] ])

# %% [markdown]
# ## Problem 6

# %%
A = Matrix([[1, 4, -1, 1],[3, 14, -1, 6], [2, 12, 2, 8] ])

# %% [markdown]
# ## Problem 7

# %%
A = Matrix([[1, 1, 1], [1, 2, 2], [-2, -4, -3], [0, 1, 1]])

# %% [markdown]
# ## Problem 8

# %%
A = Matrix([[1, 1, 2, 7], [2, -2, 0, -2], [-4, 3, -1, 0], [-4, 1, -3, -8]])

# %% [markdown]
# ## Problem 10

# %%
A = Matrix([[1, 2, 4, 8, 0], [1, 3, 9, 27, 0]])

# %% [markdown]
# ## Group Problem 1c

# %%
A = Matrix([[4, -3, 2, -1], [0, 0, 2, -1], [0, 1, 1, -5/6]])

# %% [markdown]
# # Solve It

# %%
D_frac = A.applyfunc(lambda x: Rational(str(x)))
D_frac.rref()[0]
# Out:
# Matrix([
# [1, 0, 0, -999999999999999/4000000000000000],
# [0, 1, 0, -333333333333333/1000000000000000],
# [0, 0, 1,                              -1/2]])
