# %% [markdown]
# # Week 3 Group Activity

# %%
from sympy import linsolve, symbols, Eq, Matrix, S

# %% [markdown]
# x, y, z = symbols('x, y, z')
# A = Matrix(([0,-1,1,30], [0, 1, -1, 30], [1,0,-1,115]))
# linsolve(A, (x, y, z))

# %%
x, y, z = symbols('x, y, z')
A = Matrix(([0,-1,1,30], [0, 1, -1, 30], [1,0,-1,115]))
linsolve(A, (x, y, z))
# Out:
# EmptySet

# %% [markdown]
# Problem 3

# %%
x, y = symbols('x, y')
A = Matrix(([1, 2, -1, -2], [2, -1, 1, 5]))
linsolve(A, (x, y))
# Out:
# {(8/5, -9/5)}

# %%
x, y = symbols('x, y')
A = Matrix(([1, 2, -1, 0], [2, -1, 1, 0]))
linsolve(A, (x, y))
# Out:
# {(0, 0)}
