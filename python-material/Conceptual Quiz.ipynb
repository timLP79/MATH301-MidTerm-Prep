# %% [markdown]
# # Conceptual Quiz

# %%
import sympy as sp
from sympy import Matrix, S, Rational

# %%
A = Matrix([[3,0,-2,1], [4,1,0,-1]])

# %%
D_frac = A.applyfunc(lambda x: Rational(str(x)))
D_frac.rref()[0]
# Out:
# Matrix([
# [1, 0, -2/3,  1/3],
# [0, 1,  8/3, -7/3]])
