# %%
from sympy import linsolve, symbols, Eq, Matrix, S

# %% [markdown]
# Problem 6

# %%
x, y, z, w = symbols('x, y, z, w')
A = Matrix(([1, 1, 0, 0, -2], [0, 1, 1, 0, -3], [0, 0, 1, 1, -2], [1, 0, 0, 1, -1]))
linsolve(A, (x, y, z, w))
# Out:
# {(-w - 1, w - 1, -w - 2, w)}

# %%
x, y, z, w = symbols('x, y, z, w')
A = Matrix(([1, 1, 0, 0, -2], [0, 1, 1, 0, -3], [0, 0, 1, 1, -2], [1, 0, 0, 1, -1]))
linsolve(A, (x, y, z, w))
